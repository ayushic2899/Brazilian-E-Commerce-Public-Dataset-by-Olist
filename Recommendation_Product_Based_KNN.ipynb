# %% [markdown]
# # Nearest Neighbor product based Collaborative Filtering

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors

# %%
combined=pd.read_csv("Combined.csv")

# %%
combined.head()
# Out:
#    Unnamed: 0                          order_id  order_item_id  \
# 0           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1           1  130898c0987d1801452a8ed92a670612              1
# 2           2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3           3  6f8c31653edb8c83e1a739408b5ff750              1
# 4           4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   55.9
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   64.9
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
#
#    freight_value product_category_name                       customer_id  \
# 0          13.29            cool_stuff  3ce436f183e68e07877b285a838db11a
# 1          17.96            cool_stuff  e6eecc5a77de221464d1c4eaff0a9b64
# 2          18.33            cool_stuff  4ef55bf80f711b372afebcb7c715344a
# 3          16.17            cool_stuff  30407a72ad8b3f4df4d15369126b20c9
# 4          13.29            cool_stuff  91a792fef70ecd8cc69d3c7feb3d12da
#
#                           review_id  review_score review_comment_title  \
# 0  97ca439bc427b48bc1cd7177abe71365             5     Super recomended
# 1  b11cba360bbe71410c291b764753d37f             5     Super recomended
# 2  af01c4017c5ab46df6cc810e069e654a             4           Recomended
# 3  8304ff37d8b16b57086fa283fe0c44f8             5     Super recomended
# 4  426f43a82185969503fb3c86241a9535             5     Super recomended
#
#   review_creation_date review_answer_timestamp  \
# 0  2017-09-21 00:00:00     2017-09-22 10:57:03
# 1  2017-07-14 00:00:00     2017-07-17 12:50:07
# 2  2018-06-05 00:00:00     2018-06-06 21:41:12
# 3  2017-08-10 00:00:00     2017-08-13 03:35:17
# 4  2017-08-25 00:00:00     2017-08-28 00:51:18
#
#                  customer_unique_id          customer_city customer_state  \
# 0  871766c5855e863f6eccc05f988b23cb  campos dos goytacazes             RJ
# 1  0fb8e3eab2d3e79d92bb3fffbb97f188                  jatai             GO
# 2  3419052c8c6b45daf79c1e426f9e9bcb         belo horizonte             MG
# 3  e7c828d22c0682c1565252deefbe334d   sao jose dos pinhais             PR
# 4  0bb98ba72dcc08e95f9d8cc434e9a2cc   conselheiro lafaiete             MG
#
#      seller_city seller_state product_category_name_english
# 0  volta redonda           SP                    cool_stuff
# 1  volta redonda           SP                    cool_stuff
# 2  volta redonda           SP                    cool_stuff
# 3  volta redonda           SP                    cool_stuff
# 4  volta redonda           SP                    cool_stuff

# %%
df1=pd.read_csv("combined.csv",usecols=['product_id','customer_unique_id','product_category_name_english','review_score'])

# %%
df1.head()
# Out:
#                          product_id  review_score  \
# 0  4244733e06e7ecb4970a6e2683c13e61             5
# 1  4244733e06e7ecb4970a6e2683c13e61             5
# 2  4244733e06e7ecb4970a6e2683c13e61             4
# 3  4244733e06e7ecb4970a6e2683c13e61             5
# 4  4244733e06e7ecb4970a6e2683c13e61             5
#
#                  customer_unique_id product_category_name_english
# 0  871766c5855e863f6eccc05f988b23cb                    cool_stuff
# 1  0fb8e3eab2d3e79d92bb3fffbb97f188                    cool_stuff
# 2  3419052c8c6b45daf79c1e426f9e9bcb                    cool_stuff
# 3  e7c828d22c0682c1565252deefbe334d                    cool_stuff
# 4  0bb98ba72dcc08e95f9d8cc434e9a2cc                    cool_stuff

# %% [markdown]
# Combine total product review and count the total reviews

# %%
combine_product_review = df1.dropna(axis = 0, subset = ['product_category_name_english'])
product_reviewCount = (combine_product_review.
     groupby(by = ['product_category_name_english'])['review_score'].
     count().
     reset_index().
     rename(columns = {'review_score': 'totalReviewCount'})
     [['product_category_name_english','totalReviewCount']]
    )
product_reviewCount.head()
# Out:
#   product_category_name_english  totalReviewCount
# 0    agro_industry_and_commerce               241
# 1              air_conditioning               279
# 2                           art               209
# 3         arts_and_craftmanship                19
# 4                         audio               362

# %% [markdown]
# # After merging Total review count column into dataset

# %%
review_with_totalReviewCount  = combine_product_review.merge(product_reviewCount, left_on = 'product_category_name_english', right_on = 'product_category_name_english', how = 'left')
review_with_totalReviewCount.head()
# Out:
#                          product_id  review_score  \
# 0  4244733e06e7ecb4970a6e2683c13e61             5
# 1  4244733e06e7ecb4970a6e2683c13e61             5
# 2  4244733e06e7ecb4970a6e2683c13e61             4
# 3  4244733e06e7ecb4970a6e2683c13e61             5
# 4  4244733e06e7ecb4970a6e2683c13e61             5
#
#                  customer_unique_id product_category_name_english  \
# 0  871766c5855e863f6eccc05f988b23cb                    cool_stuff
# 1  0fb8e3eab2d3e79d92bb3fffbb97f188                    cool_stuff
# 2  3419052c8c6b45daf79c1e426f9e9bcb                    cool_stuff
# 3  e7c828d22c0682c1565252deefbe334d                    cool_stuff
# 4  0bb98ba72dcc08e95f9d8cc434e9a2cc                    cool_stuff
#
#    totalReviewCount
# 0              3847
# 1              3847
# 2              3847
# 3              3847
# 4              3847

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(product_reviewCount['totalReviewCount'].describe())
# Out:
# count      71.000
# mean     1522.141
# std      2518.406
# min         2.000
# 25%        92.000
# 50%       279.000
# 75%      1788.000
# max     10647.000
# Name: totalReviewCount, dtype: float64

# %% [markdown]
# filtering out products that have less than 100 reviews

# %%
popularity_threshold =100
review_popular_product= review_with_totalReviewCount.query('totalReviewCount >= @popularity_threshold')
review_popular_product.head()
# Out:
#                          product_id  review_score  \
# 0  4244733e06e7ecb4970a6e2683c13e61             5
# 1  4244733e06e7ecb4970a6e2683c13e61             5
# 2  4244733e06e7ecb4970a6e2683c13e61             4
# 3  4244733e06e7ecb4970a6e2683c13e61             5
# 4  4244733e06e7ecb4970a6e2683c13e61             5
#
#                  customer_unique_id product_category_name_english  \
# 0  871766c5855e863f6eccc05f988b23cb                    cool_stuff
# 1  0fb8e3eab2d3e79d92bb3fffbb97f188                    cool_stuff
# 2  3419052c8c6b45daf79c1e426f9e9bcb                    cool_stuff
# 3  e7c828d22c0682c1565252deefbe334d                    cool_stuff
# 4  0bb98ba72dcc08e95f9d8cc434e9a2cc                    cool_stuff
#
#    totalReviewCount
# 0              3847
# 1              3847
# 2              3847
# 3              3847
# 4              3847

# %%
review_popular_product.shape
# Out:
# (107383, 5)

# %% [markdown]
# # create a Pivot matrix

# %%
product_features_df=review_popular_product.pivot_table(index='product_category_name_english',columns='customer_unique_id',values='review_score').fillna(0)
product_features_df.head()
# Out:
# customer_unique_id             0000366f3b9a7992bf8c76cfdf3221e2  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             0000b849f77a49e4a4ce2b2a4ca5be3f  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             0000f46a3911fa3c0805444483337064  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             0000f6ccb0745a6a4b88665a16c9f078  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             0004aac84e0df4da2b147fca70cf8255  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             0004bd2a26a76fe21f786e4fbd80607f  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             00050ab1314c0e55a6ca13cf7181fecf  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             00053a61a98854899e70ed204dd4bafe  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             0005e1862207bf6ccc02e4228effd9a0  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             0005ef4cd20d2893f0d9fbd94d3c0d97  ...  \
# product_category_name_english                                    ...
# agro_industry_and_commerce                                0.000  ...
# air_conditioning                                          0.000  ...
# art                                                       0.000  ...
# audio                                                     0.000  ...
# auto                                                      0.000  ...
#
# customer_unique_id             fff7219c86179ca6441b8f37823ba3d3  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             fff96bc586f78b1f070da28c4977e810  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             fffa431dd3fcdefea4b1777d114144f2  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             fffb09418989a0dbff854a28163e47c6  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             fffcc512b7dfecaffd80f13614af1d16  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             fffcf5a5ff07b0908bd4e2dbc735a684  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             fffea47cd6d3cc0a88bd621562a9d061  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             ffff371b4d645b6ecea244b27531430a  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      5.000
#
# customer_unique_id             ffff5962728ec6157033ef9805bacc48  \
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# customer_unique_id             ffffd2657e2aad2907e67c3e9daecbeb
# product_category_name_english
# agro_industry_and_commerce                                0.000
# air_conditioning                                          0.000
# art                                                       0.000
# audio                                                     0.000
# auto                                                      0.000
#
# [5 rows x 90515 columns]

# %%
from scipy.sparse import csr_matrix

product_features_df_matrix = csr_matrix(product_features_df.values)

# %%
from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(product_features_df_matrix)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %%
product_features_df.shape
# Out:
# (53, 90515)

# %% [markdown]
# # choose a random product

# %%
query_index = np.random.choice(product_features_df.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(product_features_df.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# 34

# %% [markdown]
# # Based on that product what we have choosen 5 nearest distance product get recommended

# %%
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(product_features_df.index[query_index]))
    else:
        print('{0}: {1}, with distance of {2}:'.format(i, product_features_df.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for home_appliances_2:
#
# 1: bed_bath_table, with distance of 0.9996340565324598:
# 2: home_construction, with distance of 1.0:
# 3: industry_commerce_and_business, with distance of 1.0:
# 4: housewares, with distance of 1.0:
# 5: home_confort, with distance of 1.0:
